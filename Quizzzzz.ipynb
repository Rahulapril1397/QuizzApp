# %%
"""
    Quiz, Subective and Objestive test class.
"""
import pandas as pd

class Quiz:
    """
       General Informationa about quiz, and input name.
    """

    def __init__(self):
        """
            THis is doc string
        """
        self.answer = None
        self.name = None
        self.df_subjective = None
        self.df_objective = None

    def genral_instruction(self):
        """
            Print ou the genral instruction about the test.
        """
        self.name = input("Enter your name:")
        print("General Instrucion for the test.")
        print("A. In total there are 20 questions.")
        print("B. There are two types of questions subjective and objective.")
        print("C. There are 10 subjective questions carrying 1 marks each.")
        print("D. There are 10 objective questions.")
        print("First attempt subjective questions")
        print("E. For objective questions reponses should be anyone of A, B, C or D ")
        print("F. Attempt all questions.")

    def objective_quiz_data(self):
        """
            Stores the csv file of objective question in dataframe.
        """
        self.df_objective = pd.read_csv('/home/rahul/Documents/QuizApp/Objective.csv')
        return self.df_objective

    def subjective_quiz_data(self):
        """
            Stores the csv file of subjective question in dataframe.
        """
        self.df_subjective = pd.read_csv('subjective_questions.csv', sep='\t')
        return self.df_subjective

    def user_answer(self):
        """
            Stores the answer input by the user.
        """
        self.answer = []
        #for inputs in range(0, 1):
        self.answer.append(input("Your Answer: "))
        return self.answer

class ObjectiveTest(Quiz):
    """
        Ask objective question one by one and stores the input given by the user.
    """

    def __init__(self):
        Quiz.__init__(self)
        self.answer_objective = None
        self.score_obtained = None
        self.correct_answer_data = None
        self.df_objective_data = None
        self.marks = 0

    def get_objective_data(self):
        """
            This is doc string.
        """
        self.df_objective_data = Quiz.objective_quiz_data(self)

    def objective_quiz(self):
        """
            Ask the question from the stored dataframe
        """
        for row in range(0, 10):
            objective_question = self.df_objective_data.loc[row, "Questions"]
            objective_option_a = self.df_objective_data.loc[row, "A"]
            objective_option_b = self.df_objective_data.loc[row, "B"]
            objective_option_c = self.df_objective_data.loc[row, "C"]
            objective_option_d = self.df_objective_data.loc[row, "D"]

            print("Question: ", objective_question)
            print("Opt A:", objective_option_a)
            print("Opt B:", objective_option_b)
            print("Opt C:", objective_option_c)
            print("Opt D:", objective_option_d)

            self.answer_objective = Quiz.user_answer(self)

    def performance(self):
        """
            Compare the response of the user and the correct answer and oututs the score.
        """
        self.correct_answer_data = self.df_objective_data.loc[:, "Answer"]
        for i in range(0, 10):
            print(self.correct_answer_data[i])
            print(self.answer_objective)
            if self.correct_answer_data == self.answer_objective:
                self.marks += 1
        print("score", self.marks)

    def score(self):
        """
            Outputs score from the method perfromance.
        """
        self.performance()

class SubjectiveTest(Quiz):
    """
        Ask objective question one by one and stores the input given by the user.
    """

    def __init__(self):
        """
            Initializes class attributes.
        """
        Quiz.__init__(self)
        self.answer_subjective = None
        self.df_subjective_data = None

    def get_subjective_data(self):
        """
            Reads the subjective csv file using method of parent class Quiz.
        """
        self.df_subjective_data = Quiz.subjective_quiz_data(self)

    def subjective_quiz(self):
        """
            Ask subjective questions
        """
        for row in range(0, 10):
            subjective_question = self.df_subjective_data.loc[row, "Questions"]

            print("Question: ", subjective_question)

            self.answer_subjective = Quiz.user_answer(self)

            print("Correct Answer:" + self.df_subjective_data.loc[row, "Answers"])

# %%
"""
    This is main code file.
"""
import pandas as pd
from quiz import Quiz, ObjectiveTest, SubjectiveTest

if __name__ == "__main__":
     quiz = Quiz()
     objective_test = ObjectiveTest()
     #subjective_test = SubjectiveTest()
     #quiz.genral_instruction()
     #subjective_test.get_subjective_data()
     #subjective_test.subjective_quiz()
     objective_test.get_objective_data()
     objective_test.objective_quiz()
     objective_test.performance()
     #objective_test.score()
# Out:
# Question:  You're 3rd place right now in a race. What place are you in when you pass the person in 2nd place?
# Opt A: 1st
# Opt B: 2nd
# Opt C: 3rd
# Opt D: None of above
# Your Answer: A
# Question:  How many months have 28 days?
# Opt A: 1
# Opt B: 2
# Opt C: 3
# Opt D: Depends if its leap year or not
# Your Answer: D
# Question:  The Homolographic projection has the correct representation of
# Opt A: Shape
# Opt B: Area
# Opt C: Baring
# Opt D: Distance
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-28747229caec> in <module>
#      13      #subjective_test.subjective_quiz()
#      14      objective_test.get_objective_data()
# ---> 15      objective_test.objective_quiz()
#      16      objective_test.performance()
#      17      #objective_test.score()
#
# ~/Documents/QuizApp/quiz.py in objective_quiz(self)
#      91             print("Opt D:", objective_option_d)
#      92
# ---> 93             self.answer_objective = Quiz.user_answer(self)
#      94
#      95     def performance(self):
#
# ~/Documents/QuizApp/quiz.py in user_answer(self)
#      52         self.answer = []
#      53         #for inputs in range(0, 1):
# ---> 54         self.answer.append(input("Your Answer: "))
#      55         return self.answer
#      56
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:

# %%
answer = []
marks = 0
df_objective_data= pd.read_csv('Objective.csv')

def user_answer():
    """
        Stores the answer input by the user.
    """
    #for inputs in range(0, 1):
    answer.append(input("Your Answer: "))
    return answer

for row in range(0, 10):
    objective_question = df_objective_data.loc[row, "Questions"]
    objective_option_a = df_objective_data.loc[row, "A"]
    objective_option_b = df_objective_data.loc[row, "B"]
    objective_option_c = df_objective_data.loc[row, "C"]
    objective_option_d = df_objective_data.loc[row, "D"]

    print("Question: ", objective_question)
    print("Opt A:", objective_option_a)
    print("Opt B:", objective_option_b)
    print("Opt C:", objective_option_c)
    print("Opt D:", objective_option_d)

    answer_objective = user_answer()
    
correct_answer_data = df_objective_data.loc[:, "Answer"]
for i in range(0, 10):
    print(correct_answer_data)
    print(answer_objective)
    if correct_answer_data[i] == answer_objective[i]:
        marks += 1
print("score", marks)
# Out:
# Question:  You're 3rd place right now in a race. What place are you in when you pass the person in 2nd place?
# Opt A: 1st
# Opt B: 2nd
# Opt C: 3rd
# Opt D: None of above
# Your Answer: A
# Question:  How many months have 28 days?
# Opt A: 1
# Opt B: 2
# Opt C: 3
# Opt D: Depends if its leap year or not
# Your Answer: D
# Question:  The Homolographic projection has the correct representation of
# Opt A: Shape
# Opt B: Area
# Opt C: Baring
# Opt D: Distance
# Your Answer: B
# Question:  Who invented the BALLPOINT PEN?
# Opt A: Biro Brothers
# Opt B: Michael Jackson
# Opt C: Kim Jong Un
# Opt D: Write Brothers
# Your Answer: A
# Question:  What J. B. Dunlop invented?
# Opt A: Pneumatic rubber tire
# Opt B: Automobile wheel rim
# Opt C: Rubber boot
# Opt D: Model airplanes
# Your Answer: D
# Question:  Which scientist discovered the radioactive element radium?
# Opt A: Isaac Newton
# Opt B: Albert Einstein
# Opt C: Benjamin Franklin
# Opt D: Marie Curie
# Your Answer: A
# Question:  What Galileo invented?
# Opt A: Barometer
# Opt B: Pendulum clock
# Opt C: Microscope
# Opt D: Thermometer
# Your Answer: D
# Question:  What James Watt invented?
# Opt A: Diving bell
# Opt B: Steam boat
# Opt C: Hot air balloon
# Opt D: Rotary steam engine
# Your Answer: D
# Question:  Where is the village of Branston, after which the famous pickle is named?
# Opt A: Yorkshire
# Opt B: Lancashire
# Opt C: Staffordshire
# Opt D: Norfolk
# Your Answer: C
# Question:  Who invented Jet Engine?
# Opt A: Sir Frank Whittle
# Opt B: Gottlieb Daimler
# Opt C: Roger Bacon
# Opt D: Lewis E. Waterman
# Your Answer: A
# 0    A
# 1    D
# 2    B
# 3    A
# 4    A
# 5    D
# 6    D
# 7    D
# 8    C
# 9    A
# Name: Answer, dtype: object
# ['A', 'D', 'B', 'A', 'D', 'A', 'D', 'D', 'C', 'A']
# 0    A
# 1    D
# 2    B
# 3    A
# 4    A
# 5    D
# 6    D
# 7    D
# 8    C
# 9    A
# Name: Answer, dtype: object
# ['A', 'D', 'B', 'A', 'D', 'A', 'D', 'D', 'C', 'A']
# 0    A
# 1    D
# 2    B
# 3    A
# 4    A
# 5    D
# 6    D
# 7    D
# 8    C
# 9    A
# Name: Answer, dtype: object
# ['A', 'D', 'B', 'A', 'D', 'A', 'D', 'D', 'C', 'A']
# 0    A
# 1    D
# 2    B
# 3    A
# 4    A
# 5    D
# 6    D
# 7    D
# 8    C
# 9    A
# Name: Answer, dtype: object
# ['A', 'D', 'B', 'A', 'D', 'A', 'D', 'D', 'C', 'A']
# 0    A
# 1    D
# 2    B
# 3    A
# 4    A
# 5    D
# 6    D
# 7    D
# 8    C
# 9    A
# Name: Answer, dtype: object
# ['A', 'D', 'B', 'A', 'D', 'A', 'D', 'D', 'C', 'A']
# 0    A
# 1    D
# 2    B
# 3    A
# 4    A
# 5    D
# 6    D
# 7    D
# 8    C
# 9    A
# Name: Answer, dtype: object
# ['A', 'D', 'B', 'A', 'D', 'A', 'D', 'D', 'C', 'A']
# 0    A
# 1    D
# 2    B
# 3    A
# 4    A
# 5    D
# 6    D
# 7    D
# 8    C
# 9    A
# Name: Answer, dtype: object
# ['A', 'D', 'B', 'A', 'D', 'A', 'D', 'D', 'C', 'A']
# 0    A
# 1    D
# 2    B
# 3    A
# 4    A
# 5    D
# 6    D
# 7    D
# 8    C
# 9    A
# Name: Answer, dtype: object
# ['A', 'D', 'B', 'A', 'D', 'A', 'D', 'D', 'C', 'A']
# 0    A
# 1    D
# 2    B
# 3    A
# 4    A
# 5    D
# 6    D
# 7    D
# 8    C
# 9    A
# Name: Answer, dtype: object
# ['A', 'D', 'B', 'A', 'D', 'A', 'D', 'D', 'C', 'A']
# 0    A
# 1    D
# 2    B
# 3    A
# 4    A
# 5    D
# 6    D
# 7    D
# 8    C
# 9    A
# Name: Answer, dtype: object
# ['A', 'D', 'B', 'A', 'D', 'A', 'D', 'D', 'C', 'A']
# score 8
